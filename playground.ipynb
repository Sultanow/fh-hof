# %%
import pandas as pd
import pyreadstat
import matplotlib.pyplot as plt

# %%
file_path = "data/Validierungsstudie_Simulator_V1.4 ausreisserbereinigt_czaban.sav"
df, meta = pyreadstat.read_sav(file_path)

# %%
df.head()
# Out:
#     Nr  V0.1_VorTest  V0.2_VorTest  V0.3_VorTest  V0.4_VorTest  V0.5_VorTest  \
# 0  1.0           9.0           9.0           6.0           7.0          10.0
# 1  2.0           3.0           8.0           6.0           4.0           9.0
# 2  3.0           0.0          10.0           9.0           5.0          10.0
# 3  4.0           2.0           9.0           8.0           7.0           9.0
# 4  5.0           0.0          10.0           8.0           8.0          10.0
#
#    V0.6_VorTest  V0.7_VorTest  V0.8_VorTest  V0.9_VorTest  ...  \
# 0          10.0           2.0           9.0           9.0  ...
# 1          10.0           2.0           6.0           8.0  ...
# 2           9.0           0.0           8.0           4.0  ...
# 3          10.0           0.0           7.0           3.0  ...
# 4           8.0           0.0           7.0           7.0  ...
#
#    HERZdurchschnSDNN_Diff_Stadt3SFRF  Differenz_NASATLX_SFRF  \
# ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['HERZdurchschnSDNN_Diff_Stadt3SFRF'], label='HERZdurchschnSDNN_Diff_Stadt3SFRF', color='blue')
plt.title('Zeitreihe der HERZdurchschnSDNN_Diff_Stadt3SFRF')
plt.xlabel('Zeit')
plt.ylabel('Wert')
plt.legend()
plt.grid(True)
plt.show()
